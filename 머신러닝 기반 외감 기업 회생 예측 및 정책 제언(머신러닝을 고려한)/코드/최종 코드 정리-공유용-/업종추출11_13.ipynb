# %% [markdown]
# # 업종 추출 주피터 파일 #
#
# ### make_fin 모듈로 만들어진 기본 데이터 세트에 대해서 업종에 해당하는 더미 변수 열을 추가한 파일 ###
# ### 해당 파일은 2011~2013년 데이터를 기반으로 작성되었다. ###

# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명11_13_1.csv',encoding='cp949')
df1.dropna(inplace=True)
df1.reset_index(drop=True,inplace=True)

df1
# Out:
#               회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0       (주)21세기조선  40736  2010/12                   제조업
# 1           (주)3Z  12815  2010/12                   제조업
# 2     (주)ATS엔지니어링  61907  2010/12                   제조업
# 3      (주)DCFTREK  17676  2010/12                   제조업
# 4        (주)DH케미칼  40581  2010/12                   제조업
# ...           ...    ...      ...                   ...
# 3438   명신정보통신주식회사  56249  2010/12                   건설업
# 3439      명인전선(주)  49229  2010/12                   제조업
# 3440     명인제약주식회사  14581  2010/12                   제조업
# 3441    명일금속공업(주)  62328  2010/12                   제조업
# 3442     명일물류주식회사  61625  2010/12              운수 및 창고업
#
# [3443 rows x 4 columns]

# %%
df2 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명11_13_2.csv',encoding='cp949')
df2.dropna(inplace=True)
df2.reset_index(drop=True,inplace=True)

df2
# Out:
#               회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0         (유)비티투자  54082  2010/12                  부동산업
# 1         (주)명지문화  14584  2010/12                   제조업
# 2       (주)명지엘펜하임  46456  2010/12                  부동산업
# 3         (주)명진금속  51691  2010/12              도매 및 소매업
# 4        (주)명진커넥터  45595  2010/12                   제조업
# ...           ...    ...      ...                   ...
# 3409   에셋큐브운용주식회사  58487  2010/12                  부동산업
# 3410  에스더불유아이주식회사  15952  2010/12                   제조업
# 3411   에스더블유팜주식회사  15386  2010/12              도매 및 소매업
# 3412   에스더블유해운(주)  44539  2010/12              운수 및 창고업
# 3413  에스디바이오센서(주)  57968  2010/12                   제조업
#
# [3414 rows x 4 columns]

# %%
df3 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명11_13_3.csv',encoding='cp949')
df3.dropna(inplace=True)
df3.reset_index(drop=True,inplace=True)

df3
# Out:
#                회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0         (유)에스아이지  58564  2010/12                   제조업
# 1        (유)유맥에프앤알  14534  2010/12                  부동산업
# 2         (주)에스디비즈  61648  2010/12              도매 및 소매업
# 3       (주)에스디산업개발  50555  2010/12                  부동산업
# 4     (주)에스디엔제이홀딩스  56760  2010/12   예술, 스포츠 및 여가관련 서비스업
# ...            ...    ...      ...                   ...
# 3293      주식회사대창철강  51753  2010/12                   제조업
# 3294        주식회사대철  17678  2010/12                   제조업
# 3295      주식회사대청공영  45355  2010/12                   건설업
# 3296     주식회사대청하이텍  57045  2010/12                   제조업
# 3297        주식회사대촌  13830  2010/12                   제조업
#
# [3298 rows x 4 columns]

# %%
df4 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명11_13_4.csv',encoding='cp949')
df4.dropna(inplace=True)
df4.reset_index(drop=True,inplace=True)

df4
# Out:
#                회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0         (유)에스아이지  58564  2010/12                   제조업
# 1        (유)유맥에프앤알  14534  2010/12                  부동산업
# 2         (주)에스디비즈  61648  2010/12              도매 및 소매업
# 3       (주)에스디산업개발  50555  2010/12                  부동산업
# 4     (주)에스디엔제이홀딩스  56760  2010/12   예술, 스포츠 및 여가관련 서비스업
# ...            ...    ...      ...                   ...
# 3293      주식회사대창철강  51753  2010/12                   제조업
# 3294        주식회사대철  17678  2010/12                   제조업
# 3295      주식회사대청공영  45355  2010/12                   건설업
# 3296     주식회사대청하이텍  57045  2010/12                   제조업
# 3297        주식회사대촌  13830  2010/12                   제조업
#
# [3298 rows x 4 columns]

# %%
df5 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명11_13_5.csv',encoding='cp949')
df5.dropna(inplace=True)
df5.reset_index(drop=True,inplace=True)

df5
# Out:
#                 회사명  거래소코드     회계년도  통계청 한국표준산업분류 10차(대분류)
# 0     (유)짐머바이오메트코리아  18711  2010/12               도매 및 소매업
# 1         (유)케이원에너지  47069  2010/12               도매 및 소매업
# 2            (주)진데크  52321  2010/12                    건설업
# 3          (주)진도선파크  60022  2010/12  전기, 가스, 증기 및 공기조절 공급업
# 4         (주)진두아이에스  52071  2010/12                  정보통신업
# ...             ...    ...      ...                    ...
# 3182        희창냉장(주)  20563  2010/12               운수 및 창고업
# 3183       희창물산주식회사  20564  2010/12               도매 및 소매업
# 3184      희창씨앤에프(주)  52850  2010/12               운수 및 창고업
# 3185       희천개발주식회사  60017  2010/12                   부동산업
# 3186      힐티코리아주식회사  10534  2010/12               도매 및 소매업
#
# [3187 rows x 4 columns]

# %%
import numpy as np

df_w = pd.concat([df1,df2,df3],axis=0)
df_w.reset_index(inplace=True,drop=True)
df_w.rename(columns={'회사명':'구분'},inplace=True)
df_w.rename(columns={'통계청 한국표준산업분류 10차(대분류)':'업종'},inplace=True)
df_w.set_index('구분',inplace=True)
df_w = df_w['업종']
df_w
# len(np.unique(df_w.index))
# Out:
# 구분
# (주)21세기조선      제조업
# (주)3Z          제조업
# (주)ATS엔지니어링    제조업
# (주)DCFTREK     제조업
# (주)DH케미칼       제조업
#               ...
# 주식회사대창철강       제조업
# 주식회사대철         제조업
# 주식회사대청공영       건설업
# 주식회사대청하이텍      제조업
# 주식회사대촌         제조업
# Name: 업종, Length: 10155, dtype: object

# %%
df13 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(더미전)/충격기간/11_13_이자.csv',encoding='cp949')
df13.set_index('구분',inplace=True)
df13 = df13.join(df_w,how='left')
df13['업종'][df13['업종'] != '제조업'] = 1
df13['업종'][df13['업종'] == '제조업'] = 0
ind = df13['업종']
df13.drop('업종',axis=1,inplace=True)
df13.insert(loc=27,column='업종',value=ind)
df13
# 비제조업 1, 제조업 0
df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(업종추가)/충격기간/11_13_이자(업종더미).csv',encoding='cp949')
df13
# df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/충격기간/00_02_이자(업종포함).csv',encoding='cp949')
# 업종 추가 결과 데이터 숫자가 더 늘어나게 되는데
# 특정 기업이 여러 업종에서 사업을 진행할 경우 
# 해당 업종별로 개별 데이터로 취급하기 때문이다.
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_18168\1256897118.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_18168\1256897118.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] == '제조업'] = 0
#            총자산증가율2013  유동자산증가율2013  매출액증가율2013  매출액순이익률2013  매출원가대매출액비율2013  \
# 구분
# (주)EG메탈     -0.033750     0.007592    0.490788    -0.028923        0.960242
# (주)ENS      -0.019716     0.001116   -0.088468     0.008199        0.645804
# (주)G1네트웍스    0.170970     0.634374   -0.041372    -0.018864        0.882404
# (주)IEN한창    -0.029745    -0.039138   -0.031394    -0.074348        0.796686
# (주)KH엘텍      0.415425     1.525045    2.756221     0.168835        0.786241
# ...               ...          ...         ...          ...             ...
# 효성정밀주식회사     0.054786     0.091499    0.649919     0.012995        0.886434
# 효창산업주식회사     0.002700     0.364470    2.113919    -0.007388        0.923055
# 후지라이테크(주)   -0.102788     0.038909    0.099363    -0.057795        0.723034
# 휘닉스중앙주식회사    0.050982     0.237519   -0.118862    -0.287070        0.000000
# 흥일기업주식회사    -0.142372    -0.173444   -0.342661    -0.246601        1.103289
#
#            자기자본순이익률2013  총자산순이익률2013  매출액대판매관리비2013  매출채권회전율2013  재고자산회전율2013  \
# 구분
# (주)EG메탈       -0.039012    -0.025247       0.039124    14.202716     2.805940
# (주)ENS         0.052890     0.008795       0.338175     2.312957     1.845682
# (주)G1네트웍스     -0.095160    -0.023470       0.140876    11.872070    63.271474
# (주)IEN한창      -0.045440    -0.023982       0.138464     5.191184     1.865613
# (주)KH엘텍        0.674809     0.264764       0.050388    11.179282    14.965909
# ...                 ...          ...            ...          ...          ...
# 효성정밀주식회사       0.066778     0.023583       0.100304     6.327822    34.877109
# 효창산업주식회사      -0.030133    -0.012261       0.065745     8.885463   111.427440
# 후지라이테크(주)     -0.085304    -0.035930       0.213874    10.028890     4.177127
# 휘닉스중앙주식회사     -0.232974    -0.034673       1.015265     9.710098     0.000000
# 흥일기업주식회사      -0.400802    -0.117972       0.179922     3.980734     5.421254
#
#            ...  현금비율2013  부채/자산2013  부채/매출액2013  부채/현금흐름2013  유동부채/부채2013  \
# 구분         ...
# (주)EG메탈    ...  0.441975   0.352838    0.404217    -2.643334     0.140536
# (주)ENS     ...  0.000165   0.833718    0.777214  -323.355008     0.760888
# (주)G1네트웍스  ...  0.246491   0.753365    0.605537    46.076679     0.418478
# (주)IEN한창   ...  0.039032   0.472221    1.463933   -20.769288     0.797238
# (주)KH엘텍    ...  0.228635   0.607646    0.387485     5.935186     0.764032
# ...        ...       ...        ...         ...          ...          ...
# 효성정밀주식회사   ...  0.159140   0.646842    0.356435     8.510644     0.885069
# 효창산업주식회사   ...  0.143773   0.593108    0.357369    84.090383     0.830754
# 후지라이테크(주)  ...  0.185574   0.578799    0.931014    29.058857     0.862307
# 휘닉스중앙주식회사  ...  0.259200   0.851173    7.047176   107.228214     0.056346
# 흥일기업주식회사   ...  0.053134   0.705660    1.475065   372.280605     0.366019
#
#            현금흐름/매출액2013  차입금평균금리2013  이자보상배율2013  업종  정상기업여부
# 구분
# (주)EG메탈       -0.152919         4.17    0.043679   1       0
# (주)ENS        -0.002404         9.10    0.676762   0       0
# (주)G1네트웍스      0.013142         0.30  -26.817797   1       0
# (주)IEN한창      -0.070485         3.86    1.501127   0       1
# (주)KH엘텍        0.065286         5.56   13.747664   0       1
# ...                 ...          ...         ...  ..     ...
# 효성정밀주식회사       0.041881         4.62    2.567857   1       1
# 효창산업주식회사       0.004250         2.15    2.044561   1       1
# 후지라이테크(주)      0.032039         2.64    3.025927   1       1
# 휘닉스중앙주식회사      0.065721        11.35   -0.077589   1       0
# 흥일기업주식회사       0.003962         5.05   -5.316400   1       0
#
# [1059 rows x 29 columns]

# %%
df13 = df13 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(더미전)/충격기간/11_13_영손.csv',encoding='cp949')
df13.set_index('구분',inplace=True)
df13 = df13.join(df_w,how='left')
df13['업종'][df13['업종'] != '제조업'] = 1
df13['업종'][df13['업종'] == '제조업'] = 0
ind = df13['업종']
df13.drop('업종',axis=1,inplace=True)
df13.insert(loc=27,column='업종',value=ind)
df13
# 비제조업 1, 제조업 0
df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(업종추가)/충격기간/11_13_영손(업종더미).csv',encoding='cp949')
df13
# df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/충격기간/00_02_영손(업종포함).csv',encoding='cp949')
# 업종 추가 결과 데이터 숫자가 더 늘어나게 되는데
# 특정 기업이 여러 업종에서 사업을 진행할 경우 
# 해당 업종별로 개별 데이터로 취급하기 때문이다.
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_18168\3610589367.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_18168\3610589367.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] == '제조업'] = 0
#              총자산증가율2013  유동자산증가율2013  매출액증가율2013  매출액순이익률2013  매출원가대매출액비율2013  \
# 구분
# (주)EG메탈       -0.033750     0.007592    0.490788    -0.028923        0.960242
# (주)G1네트웍스      0.170970     0.634374   -0.041372    -0.018864        0.882404
# (주)KH엘텍        0.415425     1.525045    2.756221     0.168835        0.786241
# (주)SIMPAC산기    0.161903     1.168194    2.155182    -0.314684        0.958029
# (주)가야          0.004088     0.091580   -0.112453     0.093197        0.914319
# ...                 ...          ...         ...          ...             ...
# 현대아산주식회사      -0.002264     0.155155    0.091379    -0.081133        0.913572
# 현대종합물산(주)      0.019752     0.106532   -0.013713     0.006527        0.906101
# 홍원제지(주)       -0.043866    -0.051812   -0.111114    -0.039178        0.955231
# 화순컨트리클럽       -0.005314     0.898652    0.050091    -0.080132        0.682314
# 효창산업주식회사       0.002700     0.364470    2.113919    -0.007388        0.923055
#
#              자기자본순이익률2013  총자산순이익률2013  매출액대판매관리비2013  매출채권회전율2013  \
# 구분
# (주)EG메탈         -0.039012    -0.025247       0.039124    14.202716
# (주)G1네트웍스       -0.095160    -0.023470       0.140876    11.872070
# (주)KH엘텍          0.674809     0.264764       0.050388    11.179282
# (주)SIMPAC산기     -0.178585    -0.101856       0.130921     3.718944
# (주)가야            0.463049     0.108646       0.054327     3.561145
# ...                   ...          ...            ...          ...
# 현대아산주식회사        -0.140603    -0.045546       0.144072     4.455844
# 현대종합물산(주)        0.006979     0.005567       0.134538     5.915732
# 홍원제지(주)         -0.114288    -0.034933       0.069549     6.842562
# 화순컨트리클럽         -0.017899    -0.006543       0.491664   226.235485
# 효창산업주식회사        -0.030133    -0.012261       0.065745     8.885463
#
#              재고자산회전율2013  ...  현금비율2013  부채/자산2013  부채/매출액2013  부채/현금흐름2013  \
# 구분                        ...
# (주)EG메탈         2.805940  ...  0.441975   0.352838    0.404217    -2.643334
# (주)G1네트웍스      63.271474  ...  0.246491   0.753365    0.605537    46.076679
# (주)KH엘텍        14.965909  ...  0.228635   0.607646    0.387485     5.935186
# (주)SIMPAC산기     1.107160  ...  0.133288   0.429650    1.327403    27.177484
# (주)가야           5.777743  ...  0.045549   0.765368    0.656534   159.051125
# ...                  ...  ...       ...        ...         ...          ...
# 현대아산주식회사       12.290477  ...  0.261674   0.676063    1.204288  -108.646588
# 현대종합물산(주)      14.316033  ...  0.417659   0.202319    0.237239     7.304204
# 홍원제지(주)         3.991149  ...  0.016815   0.694341    0.778724   -40.370556
# 화순컨트리클럽        57.228098  ...  0.121495   0.634429    7.769378    82.701649
# 효창산업주식회사      111.427440  ...  0.143773   0.593108    0.357369    84.090383
#
#              유동부채/부채2013  현금흐름/매출액2013  차입금평균금리2013  이자보상배율2013  업종  정상기업여부
# 구분
# (주)EG메탈         0.140536     -0.152919         4.17    0.043679   1       1
# (주)G1네트웍스       0.418478      0.013142         0.30  -26.817797   1       0
# (주)KH엘텍         0.764032      0.065286         5.56   13.747664   0       1
# (주)SIMPAC산기     0.912180      0.048842         4.41   -3.550352   0       0
# (주)가야           0.967189      0.004128         3.91    1.497053   0       1
# ...                  ...           ...          ...         ...  ..     ...
# 현대아산주식회사        0.327388     -0.011084         3.02  -43.444668   1       0
# 현대종합물산(주)       0.734252      0.032480         5.41  -19.104074   1       0
# 홍원제지(주)         0.838632     -0.019289         3.77   -1.081182   1       0
# 화순컨트리클럽         0.173649      0.093945         0.00   -2.036865   1       0
# 효창산업주식회사        0.830754      0.004250         2.15    2.044561   1       1
#
# [471 rows x 29 columns]
