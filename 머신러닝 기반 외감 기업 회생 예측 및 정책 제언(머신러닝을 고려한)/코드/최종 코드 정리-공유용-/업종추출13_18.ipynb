# %% [markdown]
# # 업종 추출 주피터 파일 #
#
# ### make_fin 모듈로 만들어진 기본 데이터 세트에 대해서 업종에 해당하는 더미 변수 열을 추가한 파일 ###
# ### 해당 파일은 2013~2018년의 정상기간 데이터에 대해서 작성되었다. ###

# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명12_18_1.csv',encoding='cp949')
df1.dropna(inplace=True)
df1.reset_index(drop=True,inplace=True)

df1
# Out:
#              회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0          (주)3Z  12815  2018/12                   제조업
# 1       (주)88스테이  81962  2018/12                  부동산업
# 2       (주)A.M.C  64118  2018/12                   제조업
# 3     (주)DCFTREK  17676  2018/12                   제조업
# 4       (주)DH케미칼  40581  2018/12                   제조업
# ...          ...    ...      ...                   ...
# 3719   동덕산업가스(주)  46182  2018/12                   제조업
# 3720   동덕정보통신(주)  73877  2018/12              도매 및 소매업
# 3721     동도건설(주)  14039  2018/12                   건설업
# 3722    동도디앤씨(주)  42171  2018/12                   건설업
# 3723   동도씨앤디주식회사  69794  2018/12                  부동산업
#
# [3724 rows x 4 columns]

# %%
df2 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명12_18_2.csv',encoding='cp949')
df2.dropna(inplace=True)
df2.reset_index(drop=True,inplace=True)

df2
# Out:
#               회사명  거래소코드     회계년도    통계청 한국표준산업분류 10차(대분류)
# 0         (주)동도전자  14041  2018/12                      제조업
# 1     (주)동래온천관광호텔  87237  2018/12                숙박 및 음식점업
# 2        (주)동림모스텍  80815  2018/12                 운수 및 창고업
# 3         (주)동림수산  46127  2018/12                      제조업
# 4         (주)동림유화  41229  2018/12                      제조업
# ...           ...    ...      ...                      ...
# 3601   삼지석재공업주식회사  15178  2018/12                      제조업
# 3602   삼지정밀기계주식회사  63574  2018/12                      제조업
# 3603      삼지토건(주)  43997  2018/12                      건설업
# 3604     삼진기업주식회사  24180  2018/12  수도, 하수 및 폐기물 처리, 원료 재생업
# 3605      삼진로푸(주)  65154  2018/12                      제조업
#
# [3606 rows x 4 columns]

# %%
df3 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명12_18_3.csv',encoding='cp949')
df3.dropna(inplace=True)
df3.reset_index(drop=True,inplace=True)

df3
# Out:
#                  회사명  거래소코드     회계년도  통계청 한국표준산업분류 10차(대분류)
# 0           (유)새천안교통  89201  2018/12               운수 및 창고업
# 1          (주)삼진앤컴퍼니  15181  2018/12                   부동산업
# 2           (주)삼진일렉스  52542  2018/12                    건설업
# 3            (주)삼진전선  41282  2018/12                    제조업
# 4            (주)삼진정밀  38845  2018/12                    제조업
# ...              ...    ...      ...                    ...
# 3621     에스앤에스엠텍주식회사  72842  2018/12                    제조업
# 3622    에스앤에스이앤지주식회사  59774  2018/12                    제조업
# 3623     에스앤에스케어텍(주)  80268  2018/12               도매 및 소매업
# 3624      에스앤이에너지(주)  76349  2018/12  전기, 가스, 증기 및 공기조절 공급업
# 3625  에스앤제이이노베이션주식회사  71004  2018/12               도매 및 소매업
#
# [3626 rows x 4 columns]

# %%
df4 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명12_18_4.csv',encoding='cp949')
df4.dropna(inplace=True)
df4.reset_index(drop=True,inplace=True)

df4
# Out:
#                회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0        (유)유맥에프앤알  14534  2018/12                  부동산업
# 1          (주)에스앤지  60521  2018/12                   제조업
# 2      (주)에스앤지바이오텍  82030  2018/12                   제조업
# 3       (주)에스앤지컴퍼니  56486  2018/12                   제조업
# 4     (주)에스앤지홀딩스서울  89402  2018/12                  부동산업
# ...            ...    ...      ...                   ...
# 3571      인성제약주식회사  89564  2018/12                   제조업
# 3572      인성피앤씨(주)  61151  2018/12                   제조업
# 3573        인셀주식회사  77133  2018/12                   제조업
# 3574        인솔주식회사  88739  2018/12                   제조업
# 3575      인수약품주식회사  69195  2018/12              도매 및 소매업
#
# [3576 rows x 4 columns]

# %%
df5 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명12_18_5.csv',encoding='cp949')
df5.dropna(inplace=True)
df5.reset_index(drop=True,inplace=True)

df5
# Out:
#                회사명  거래소코드     회계년도     통계청 한국표준산업분류 10차(대분류)
# 0           (주)인스빌  39379  2018/12                      부동산업
# 1        (주)인스타디앤씨  87283  2018/12                      부동산업
# 2           (주)인스텍  85404  2018/12                       제조업
# 3            (주)인아  82697  2018/12                       제조업
# 4      (주)인아오리엔탈모터  25922  2018/12                       제조업
# ...            ...    ...      ...                       ...
# 3751  주식회사삼육리더스라이프  81833  2018/12  협회 및 단체, 수리 및 기타 개인 서비스업
# 3752     주식회사삼융시네마  91582  2018/12                      부동산업
# 3753    주식회사삼익유니버스  69725  2018/12                      부동산업
# 3754    주식회사삼익티디에프  52316  2018/12                       제조업
# 3755      주식회사삼인건설  82195  2018/12                       건설업
#
# [3756 rows x 4 columns]

# %%
df6 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명12_18_6.csv',encoding='cp949')
df6.dropna(inplace=True)
df6.reset_index(drop=True,inplace=True)

df6
# Out:
#                 회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0          주식회사삼일산업  81417  2018/12              도매 및 소매업
# 1        주식회사삼일에쓰아이  71265  2018/12                  부동산업
# 2         주식회사삼일이엔씨  81434  2018/12                  부동산업
# 3         주식회사삼일이엔씨  71111  2018/12                  부동산업
# 4          주식회사삼일통상  52616  2018/12              도매 및 소매업
# ...             ...    ...      ...                   ...
# 3785  주식회사최고좋은터행복한집  81447  2018/12                  부동산업
# 3786   주식회사최신EPPEPS  59563  2018/12                   제조업
# 3787       주식회사충남고속  26812  2018/12              운수 및 창고업
# 3788       주식회사충주산업  84889  2018/12                   제조업
# 3789         주식회사친구  87052  2018/12                  부동산업
#
# [3790 rows x 4 columns]

# %%
df7 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명12_18_7.csv',encoding='cp949')
df7.dropna(inplace=True)
df7.reset_index(drop=True,inplace=True)

df7
# Out:
#              회사명  거래소코드     회계년도    통계청 한국표준산업분류 10차(대분류)
# 0          (주)주안  78796  2018/12                     부동산업
# 1          (주)주안  84937  2018/12                      제조업
# 2          (주)주영  85463  2018/12                      제조업
# 3        (주)주영토건  89235  2018/12                      건설업
# 4      (주)주영페이퍼텍  70977  2018/12                      제조업
# ...          ...    ...      ...                      ...
# 3652  태산종합건설주식회사  26928  2018/12                      건설업
# 3653    태산테크주식회사  66114  2018/12                      제조업
# 3654  태산하이테크주식회사  87236  2018/12                      제조업
# 3655  태서리사이클링(주)  19376  2018/12  수도, 하수 및 폐기물 처리, 원료 재생업
# 3656   태성글로벌주식회사  90489  2018/12                 도매 및 소매업
#
# [3657 rows x 4 columns]

# %%
df8 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/기업업종 종합/기업명12_18_8.csv',encoding='cp949')
df8.dropna(inplace=True)
df8.reset_index(drop=True,inplace=True)

df8
# Out:
#             회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0       (주)태성기연  43667  2018/12                   제조업
# 1       (주)태성기전  82372  2018/12                   제조업
# 2      (주)태성비앤피  53635  2018/12                  부동산업
# 3       (주)태성비철  57262  2018/12              도매 및 소매업
# 4     (주)태성에스앤디  83308  2018/12                   건설업
# ...         ...    ...      ...                   ...
# 3296       힐리언스  49187  2018/12             숙박 및 음식점업
# 3297   힐링홈스주식회사  84799  2018/12                   건설업
# 3298   힐중공업주식회사  82007  2018/12                   제조업
# 3299  힐티코리아주식회사  10534  2018/12              도매 및 소매업
# 3300  （주）신미코스메틱  85105  2018/12              도매 및 소매업
#
# [3301 rows x 4 columns]

# %%
import numpy as np

df_w = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8],axis=0)
df_w.reset_index(inplace=True,drop=True)
df_w.rename(columns={'회사명':'구분'},inplace=True)
df_w.rename(columns={'통계청 한국표준산업분류 10차(대분류)':'업종'},inplace=True)
df_w.set_index('구분',inplace=True)
df_w = df_w['업종']
df_w
# Out:
# 구분
# (주)3Z               제조업
# (주)88스테이           부동산업
# (주)A.M.C            제조업
# (주)DCFTREK          제조업
# (주)DH케미칼            제조업
#                 ...
# 힐리언스          숙박 및 음식점업
# 힐링홈스주식회사            건설업
# 힐중공업주식회사            제조업
# 힐티코리아주식회사      도매 및 소매업
# （주）신미코스메틱      도매 및 소매업
# Name: 업종, Length: 29036, dtype: object

# %%
df13 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(더미전)/정상기간/14_16_이자.csv',encoding='cp949')
df13.set_index('구분',inplace=True)
df13 = df13.join(df_w,how='left')
# df13.index[df13['업종']=='금융 및 보험업']
df13['업종'][df13['업종'] != '제조업'] = 1
df13['업종'][df13['업종'] == '제조업'] = 0
ind = df13['업종']
df13.drop('업종',axis=1,inplace=True)
df13.insert(loc=27,column='업종',value=ind)
df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(업종추가)/정상기간/14_16_이자(업종더미).csv',encoding='cp949')
df13
# 비제조업 1, 제조업 0
# df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/더미화/정상기간/13_15_이자(업종더미).csv',encoding='cp949')
# 업종 추가 결과 데이터 숫자가 더 늘어나게 되는데
# 특정 기업이 여러 업종에서 사업을 진행할 경우 
# 해당 업종별로 개별 데이터로 취급하기 때문이다.
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\553324746.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\553324746.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] == '제조업'] = 0
#               총자산증가율2016  유동자산증가율2016  매출액증가율2016  매출액순이익률2016  \
# 구분
# (주)A.M.C       -0.096093    -0.225289   -0.027823    -0.189179
# (주)EG메탈         0.022418     0.188799   -0.398421    -0.066588
# (주)JBM         -0.054860    -0.166440    0.029369     0.005861
# ...

# %%
df13 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(더미전)/정상기간/14_16_영손.csv',encoding='cp949')
df13.set_index('구분',inplace=True)
df13 = df13.join(df_w,how='left')
# df13.index[df13['업종']=='금융 및 보험업']
df13['업종'][df13['업종'] != '제조업'] = 1
df13['업종'][df13['업종'] == '제조업'] = 0
ind = df13['업종']
df13.drop('업종',axis=1,inplace=True)
df13.insert(loc=27,column='업종',value=ind)
df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(업종추가)/정상기간/14_16_영손(업종더미).csv',encoding='cp949')
df13
# 업종 추가 결과 데이터 숫자가 더 늘어나게 되는데
# 특정 기업이 여러 업종에서 사업을 진행할 경우 
# 해당 업종별로 개별 데이터로 취급하기 때문이다.
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\3833498223.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\3833498223.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] == '제조업'] = 0
#              총자산증가율2016  유동자산증가율2016  매출액증가율2016  매출액순이익률2016  매출원가대매출액비율2016  \
# 구분
# (주)JBM        -0.054860    -0.166440    0.029369     0.005861        0.888693
# (주)KH엘텍        0.233715     1.364335    0.123236    -0.053717        0.972109
# ...

# %%
df14 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(더미전)/정상기간/15_17_이자.csv',encoding='cp949')
df14.set_index('구분',inplace=True)
df14 = df14.join(df_w,how='left')
df14['업종'][df14['업종'] != '제조업'] = 1
df14['업종'][df14['업종'] == '제조업'] = 0
ind = df14['업종']
df14.drop('업종',axis=1,inplace=True)
df14.insert(loc=27,column='업종',value=ind)
df14.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(업종추가)/정상기간/15_17_이자(업종더미).csv',encoding='cp949')
df14
# 비제조업 1, 제조업 0
# df14.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/더미화/정상기간/14_16이자(업종더미).csv',encoding='cp949')
# df14.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/정상기간/14_16_이자(업종포함).csv',encoding='cp949')
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\236686544.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14['업종'][df14['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\236686544.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14['업종'][df14['업종'] == '제조업'] = 0
#               총자산증가율2017  유동자산증가율2017  매출액증가율2017  매출액순이익률2017  \
# 구분
# (주)A.M.C       -0.049991    -0.006009    0.010416    -0.069721
# (주)E&T         -0.004206     0.044974    0.210627     0.014755
# (주)EG메탈        -0.056968     0.009927    0.475173    -0.079229
# ...

# %%
df14 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(더미전)/정상기간/15_17_영손.csv',encoding='cp949')
df14.set_index('구분',inplace=True)
df14 = df14.join(df_w,how='left')
df14['업종'][df14['업종'] != '제조업'] = 1
df14['업종'][df14['업종'] == '제조업'] = 0
ind = df14['업종']
df14.drop('업종',axis=1,inplace=True)
df14.insert(loc=27,column='업종',value=ind)
df14.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(업종추가)/정상기간/15_17_영손(업종더미).csv',encoding='cp949')
df14
# df14.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/정상기간/14_16_영손(업종포함).csv',encoding='cp949')
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\881357131.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14['업종'][df14['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\881357131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14['업종'][df14['업종'] == '제조업'] = 0
#               총자산증가율2017  유동자산증가율2017  매출액증가율2017  매출액순이익률2017  \
# 구분
# (주)A.M.C       -0.049991    -0.006009    0.010416    -0.069721
# (주)EG메탈        -0.056968     0.009927    0.475173    -0.079229
# (주)KAL호텔네트워크   -0.038526    -0.197298   -0.069796    -0.325867
# ...

# %%
df16 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(더미전)/정상기간/16_18_이자.csv',encoding='cp949')
df16.set_index('구분',inplace=True)
df16 = df16.join(df_w,how='left')
df16['업종'][df16['업종'] != '제조업'] = 1
df16['업종'][df16['업종'] == '제조업'] = 0
ind = df16['업종']
df16.drop('업종',axis=1,inplace=True)
df16.insert(loc=27,column='업종',value=ind)
df16.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(업종추가)/정상기간/16_18_이자(업종더미).csv',encoding='cp949')
df16
# df15.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/정상기간/15_17_영손(업종포함).csv',encoding='cp949')
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\864170035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16['업종'][df16['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\864170035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16['업종'][df16['업종'] == '제조업'] = 0
#               총자산증가율2018  유동자산증가율2018  매출액증가율2018  매출액순이익률2018  \
# 구분
# (주)A.M.C       -0.034390     0.007474   -0.148821     0.011775
# (주)EG메탈        -0.580112    -0.642106   -0.473412    -0.619151
# (주)KAL호텔네트워크    0.172831    -0.154506    0.090746    -0.148328
# ...

# %%
df16 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(더미전)/정상기간/16_18_영손.csv',encoding='cp949')
df16.set_index('구분',inplace=True)
df16 = df16.join(df_w,how='left')
df16['업종'][df16['업종'] != '제조업'] = 1
df16['업종'][df16['업종'] == '제조업'] = 0
ind = df16['업종']
df16.drop('업종',axis=1,inplace=True)
df16.insert(loc=27,column='업종',value=ind)
df16.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/최종데이터종합/재무비율(업종추가)/정상기간/16_18_영손(업종더미).csv',encoding='cp949')
df16
# 비제조업 1, 제조업 0
# df16.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/더미화/정상기간/16_18이자(업종더미).csv',encoding='cp949')
# df16.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/정상기간/16_18_이자(업종포함).csv',encoding='cp949')
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\3701395674.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16['업종'][df16['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_20220\3701395674.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16['업종'][df16['업종'] == '제조업'] = 0
#               총자산증가율2018  유동자산증가율2018  매출액증가율2018  매출액순이익률2018  \
# 구분
# (주)EG메탈        -0.580112    -0.642106   -0.473412    -0.619151
# (주)KAL호텔네트워크    0.172831    -0.154506    0.090746    -0.148328
# (주)가나스틸        -0.052751    -0.056916    0.109586     0.013179
# ...
