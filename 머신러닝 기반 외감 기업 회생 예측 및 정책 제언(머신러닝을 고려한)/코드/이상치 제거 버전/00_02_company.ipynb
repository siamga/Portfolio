# %%
import pandas as pd
import numpy as np
import prepre_ver3
import re
import warnings
warnings.filterwarnings(action='ignore')

from importlib import reload
reload(prepre_ver3)
# Out:
# <module 'prepre_ver3' from 'c:\\Users\\LG\\Desktop\\금융 빅데이터\\프로젝트2\\코드\\이상치 제거 버전\\prepre_ver3.py'>

# %% [markdown]
# # 00~02 상장

# %%
a = prepre.company('../데이터/분석데이터/00_02상장데이터.csv ')
df = a.start()
start=2000
# df[df.columns.str.contains(f'{start}')]
df[df.columns[df.columns.str.contains(f'{start}')]]
# a.limit_com(start = 2000)
# a.show_limit(standard='이자보상배율')
# a.devide()
# a.select_df().to_csv('./공유할 데이터/00_02_상장_이자.csv',encoding='cp949')
# print(a.select_df().columns)
# /['정상기업여부'].value_counts()
# Out:
#     이자보상배율2000  영업이익2000 차입금의존도2000 총자본증가율2000 유동자산증가율2000 매출액증가율2000  \
# 0         1.01  50510272      48.24      -3.78      -11.29      44.94
# 1         2.71   2023710       31.5      24.65       16.38     -31.73
# 2         0.76   6174845       81.2          0           0          0
# 3         1.75   5970249      24.96       -2.7       -0.34       77.4
# 4    999999999  18850596          0     139.03      323.52     101.68
# ..         ...       ...        ...        ...         ...        ...
# 723       2.35   2483548       13.5      51.19        8.53       34.6
# 724       0.59   2586625      27.63      42.33        9.51      23.69
# 725       20.5   9216372       4.79      22.85       28.01      21.61
# 726       0.33     56515       11.8      64.74      -39.94      27.65
# 727        0.5  10266978       8.33      -4.36      -17.96       8.88
#
#     순이익증가율2000 영업이익증가율2000 매출액순이익률2000 매출액총이익률2000  ... 순운전자본비율2000 현금비율2000  \
# ...

# %%
a = prepre.company('./데이터/분석데이터/00_02상장데이터.csv ')
a.start()
a.limit_com(start = 2000)
a.show_limit(standard='영업이익')
a.devide()
a.select_df().to_csv('./공유할 데이터/00_02_상장_영손.csv',encoding='cp949')
a.select_df()['정상기업여부'].value_counts()
# Out:
# 0    31
# 1     9
# Name: 정상기업여부, dtype: int64

# %%
a = prepre.company('./데이터/분석데이터/00_02상장데이터.csv ')
a.start()
a.limit_com(start = 2000)
a.show_limit(standard='차입금의존도')
a.devide()
a.select_df().to_csv('./공유할 데이터/00_02_상장_차입.csv',encoding='cp949')
a.select_df()['정상기업여부'].value_counts()
# Out:
# 1    15
# 0     3
# Name: 정상기업여부, dtype: int64

# %% [markdown]
# # 00_02 외감

# %%
a = prepre.company('./데이터/분석데이터/00_02외감.csv ')
a.start()
a.limit_com(start = 2000)
a.show_limit(standard='이자보상배율')
a.devide()
# a.select_df().to_csv('./공유할 데이터/00_02_외감_이자.csv',encoding='cp949')
a.select_df()
# Out:
#               구분 이자보상배율2002   영업이익2002 차입금의존도2002 총자본증가율2002 유동자산증가율2002  \
# 0         (주)KHE      -6.91   -6211302      67.67     -31.77      -39.37
# 1        (주)NH무역       1.61    1748938      52.56      30.26       31.25
# 2         (주)가우디     -13.13   -1833014      82.28      -9.19        27.3
# 3      (주)강변스포렉스      -1.44   -1162486      40.63      22.39       88.94
# 4       (주)건잠디지털      -5.38   -1680458      56.19     -42.08      -32.13
# ..           ...        ...        ...        ...        ...         ...
# 844     효성석유주식회사      -0.47  -317881.0      87.14     -29.75      -77.93
# 845   후지테크코리아(주)      11.77  1069796.0       7.11       5.77        11.8
# 846    휘닉스중앙주식회사      -1.28 -5699783.0       9.32      -6.61      157.74
# 847  흥한주택종합건설(주)      -1.33 -3403573.0      128.7     -77.79      -79.51
# 848   희훈종합건설주식회사      15.61   760793.0        5.4     -18.61      -19.08
#
#     매출액증가율2002 순이익증가율2002 영업이익증가율2002 매출액순이익률2002  ... 현금비율2002       부채2002  \
# ...

# %%
a = prepre.company('./데이터/분석데이터/00_02외감.csv ')
a.start()
a.limit_com(start = 2000)
a.show_limit(standard='영업이익')
a.devide()
a.select_df().to_csv('./공유할 데이터/00_02_외감_영손.csv',encoding='cp949')
a.select_df()['정상기업여부'].value_counts()
# Out:
# 0    400
# 1    168
# Name: 정상기업여부, dtype: int64

# %%
a = prepre.company('./데이터/분석데이터/00_02외감.csv ')
a.start()
a.limit_com(start = 2000)
a.show_limit(standard='차입금의존도')
a.devide()
a.select_df().to_csv('./공유할 데이터/00_02_외감_차입.csv',encoding='cp949')
a.select_df()['정상기업여부'].value_counts()
# Out:
# 0    197
# 1     90
# Name: 정상기업여부, dtype: int64
