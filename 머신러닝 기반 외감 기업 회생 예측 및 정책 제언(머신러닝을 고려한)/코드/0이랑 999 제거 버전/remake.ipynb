# %%
import pandas as pd
import math

# %%
for j in ['이자','영손','차입']:
    for i in [13,14,15,16]:
        df = pd.read_csv(f'C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/공유할 데이터/합친놈/정상기간/{i}_{i+2}_{j}.csv',encoding='cp949').drop('Unnamed: 0',axis=1)
        df[f'부채/자산20{i+2}'] = df[f'부채20{i+2}']/df[f'자산20{i+2}']
        df[f'부채/매출액20{i+2}'] = df[f'부채20{i+2}']/df[f'매출액20{i+2}']
        df[f'유동부채/부채20{i+2}'] = df[f'유동부채20{i+2}']/df[f'부채20{i+2}']
        df[f'유동자산/자산20{i+2}'] = df[f'유동자산20{i+2}']/df[f'자산20{i+2}']
        # df[df['부채20{i+2}'] == 0]
        df.dropna(inplace=True)

        for k in df.index:
            if df[f'부채/매출액20{i+2}'][k]== math.inf or df[f'부채/매출액20{i+2}'][k]== -math.inf:
                df.drop(k,axis=0,inplace=True)

        df.drop([f'부채20{i+2}', f'자산20{i+2}', f'매출액20{i+2}',f'유동부채20{i+2}',f'유동자산20{i+2}',f'영업이익20{i+2}',f'이자보상배율20{i+2}', f'차입금의존도20{i+2}'],axis=1,inplace=True)
        df = df[['구분', f'총자본증가율20{i+2}',f'유동자산증가율20{i+2}', f'매출액증가율20{i+2}', f'순이익증가율20{i+2}', f'영업이익증가율20{i+2}', f'매출액순이익률20{i+2}',f'매출액총이익률20{i+2}', f'자기자본순이익률20{i+2}', f'총자본순이익률20{i+2}', f'매출원가 대 매출액비율20{i+2}',f'매출채권회전률20{i+2}', f'재고자산회전률20{i+2}', f'총자본회전률20{i+2}', f'유형자산회전율20{i+2}', f'부채비율20{i+2}',f'유동비율20{i+2}', f'자기자본배율20{i+2}', f'당좌비율20{i+2}', f'비유동비율20{i+2}', f'순운전자본비율20{i+2}',f'현금비율20{i+2}',f'부채/자산20{i+2}', f'부채/매출액20{i+2}', f'부채/현금흐름20{i+2}', f'유동부채/부채20{i+2}', f'유동자산/자산20{i+2}',f'매출/현금흐름20{i+2}', f'차입금평균이자율20{i+2}', f'정상기업여부']]
        df.to_csv(f'./공유할 데이터/{i}_{i+2}_{j}.csv',encoding='cp949')

# %%
for j in ['이자','영손','차입']:
    for i in [0,7]:
        df = pd.read_csv(f'C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/공유할 데이터/합친놈/충격기간/0{i}_0{i+2}_{j}.csv',encoding='cp949').drop('Unnamed: 0',axis=1)
        df[f'부채/자산200{i+2}'] = df[f'부채200{i+2}']/df[f'자산200{i+2}']
        df[f'부채/매출액200{i+2}'] = df[f'부채200{i+2}']/df[f'매출액200{i+2}']
        df[f'유동부채/부채200{i+2}'] = df[f'유동부채200{i+2}']/df[f'부채200{i+2}']
        df[f'유동자산/자산200{i+2}'] = df[f'유동자산200{i+2}']/df[f'자산200{i+2}']
        # df[df['부채200{i+2}'] == 0]
        df.dropna(inplace=True)
        
        for k in df.index:
            if df[f'부채/매출액200{i+2}'][k]== math.inf or df[f'부채/매출액200{i+2}'][k]== -math.inf:
                df.drop(k,axis=0,inplace=True)


        df.drop([f'부채200{i+2}', f'자산200{i+2}', f'매출액200{i+2}',f'유동부채200{i+2}',f'유동자산200{i+2}',f'영업이익200{i+2}',f'이자보상배율200{i+2}', f'차입금의존도200{i+2}'],axis=1,inplace=True)
        df = df[['구분', f'총자본증가율200{i+2}',f'유동자산증가율200{i+2}', f'매출액증가율200{i+2}', f'순이익증가율200{i+2}', f'영업이익증가율200{i+2}', f'매출액순이익률200{i+2}',f'매출액총이익률200{i+2}', f'자기자본순이익률200{i+2}', f'총자본순이익률200{i+2}', f'매출원가 대 매출액비율200{i+2}',f'매출채권회전률200{i+2}', f'재고자산회전률200{i+2}', f'총자본회전률200{i+2}', f'유형자산회전율200{i+2}', f'부채비율200{i+2}',f'유동비율200{i+2}', f'자기자본배율200{i+2}', f'당좌비율200{i+2}', f'비유동비율200{i+2}', f'순운전자본비율200{i+2}',f'현금비율200{i+2}',f'부채/자산200{i+2}', f'부채/매출액200{i+2}', f'부채/현금흐름200{i+2}', f'유동부채/부채200{i+2}', f'유동자산/자산200{i+2}',f'매출/현금흐름200{i+2}', f'차입금평균이자율200{i+2}', f'정상기업여부']]
        df.to_csv(f'./공유할 데이터/0{i}_0{i+2}_{j}.csv',encoding='cp949')

# %%
for i in [0,7]:
        df = pd.read_csv(f'C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/공유할 데이터/합친놈/충격기간/0{i}_0{i+2}_{j}.csv',encoding='cp949').drop('Unnamed: 0',axis=1)
        df[f'부채/자산200{i+2}'] = df[f'부채200{i+2}']/df[f'자산200{i+2}']
        df[f'부채/매출액200{i+2}'] = df[f'부채200{i+2}']/df[f'매출액200{i+2}']
        df[f'유동부채/부채200{i+2}'] = df[f'유동부채200{i+2}']/df[f'부채200{i+2}']
        df[f'유동자산/자산200{i+2}'] = df[f'유동자산200{i+2}']/df[f'자산200{i+2}']
        # df[df['부채200{i+2}'] == 0]
        df.dropna(inplace=True)
        
        for k in df.index:
            if df[f'부채/매출액200{i+2}'][k]== math.inf or df[f'부채/매출액200{i+2}'][k]== -math.inf:
                df.drop(k,axis=0,inplace=True)


        df.drop([f'부채200{i+2}', f'자산200{i+2}', f'매출액200{i+2}',f'유동부채200{i+2}',f'유동자산200{i+2}',f'영업이익200{i+2}',f'이자보상배율200{i+2}', f'차입금의존도200{i+2}'],axis=1,inplace=True)
        df = df[['구분', f'총자본증가율200{i+2}',f'유동자산증가율200{i+2}', f'매출액증가율200{i+2}', f'순이익증가율200{i+2}', f'영업이익증가율200{i+2}', f'매출액순이익률200{i+2}',f'매출액총이익률200{i+2}', f'자기자본순이익률200{i+2}', f'총자본순이익률200{i+2}', f'매출원가 대 매출액비율200{i+2}',f'매출채권회전률200{i+2}', f'재고자산회전률200{i+2}', f'총자본회전률200{i+2}', f'유형자산회전율200{i+2}', f'부채비율200{i+2}',f'유동비율200{i+2}', f'자기자본배율200{i+2}', f'당좌비율200{i+2}', f'비유동비율200{i+2}', f'순운전자본비율200{i+2}',f'현금비율200{i+2}',f'부채/자산200{i+2}', f'부채/매출액200{i+2}', f'부채/현금흐름200{i+2}', f'유동부채/부채200{i+2}', f'유동자산/자산200{i+2}',f'매출/현금흐름200{i+2}', f'차입금평균이자율200{i+2}', f'정상기업여부']]
        print(df[f'부채/매출액200{i+2}'].describe())
# Out:
# count     290.000000
# mean       20.560894
# std       174.404894
# min         0.030708
# 25%         1.018984
# 50%         2.136947
# 75%         5.517780
# max      2891.648913
# Name: 부채/매출액2002, dtype: float64
# count      1656.000000
# mean        242.896922
# std        4044.608921
# min       -3629.309137
# 25%           1.286147
# 50%           3.741472
# 75%          12.236270
# max      148174.984167
# Name: 부채/매출액2009, dtype: float64

# %%
i = 13
j = '이자'
df = pd.read_csv(f'./13_15_외감_이자.csv',encoding='cp949').drop('Unnamed: 0',axis=1)
df[f'부채/자산20{i+2}'] = df[f'부채20{i+2}']/df[f'자산20{i+2}']
df[f'부채/매출액20{i+2}'] = df[f'부채20{i+2}']/df[f'매출액20{i+2}']
df[f'유동부채/부채20{i+2}'] = df[f'유동부채20{i+2}']/df[f'부채20{i+2}']
df[f'유동자산/자산20{i+2}'] = df[f'유동자산20{i+2}']/df[f'자산20{i+2}']
# df[df['부채20{i+2}'] == 0]
df.dropna(inplace=True)

for k in df.index:
    if df[f'부채/매출액20{i+2}'][k]== math.inf or df[f'부채/매출액20{i+2}'][k]== -math.inf:
        df.drop(k,axis=0,inplace=True)

df.drop([f'부채20{i+2}', f'자산20{i+2}', f'매출액20{i+2}',f'유동부채20{i+2}',f'유동자산20{i+2}',f'영업이익20{i+2}',f'이자보상배율20{i+2}', f'차입금의존도20{i+2}'],axis=1,inplace=True)
df = df[['구분', f'총자본증가율20{i+2}',f'유동자산증가율20{i+2}', f'매출액증가율20{i+2}', f'순이익증가율20{i+2}', f'영업이익증가율20{i+2}', f'매출액순이익률20{i+2}',f'매출액총이익률20{i+2}', f'자기자본순이익률20{i+2}', f'총자본순이익률20{i+2}', f'매출원가 대 매출액비율20{i+2}',f'매출채권회전률20{i+2}', f'재고자산회전률20{i+2}', f'총자본회전률20{i+2}', f'유형자산회전율20{i+2}', f'부채비율20{i+2}',f'유동비율20{i+2}', f'자기자본배율20{i+2}', f'당좌비율20{i+2}', f'비유동비율20{i+2}', f'순운전자본비율20{i+2}',f'현금비율20{i+2}',f'부채/자산20{i+2}', f'부채/매출액20{i+2}', f'부채/현금흐름20{i+2}', f'유동부채/부채20{i+2}', f'유동자산/자산20{i+2}',f'매출/현금흐름20{i+2}', f'차입금평균이자율20{i+2}', f'정상기업여부']]
df.to_csv(f'./{i}_{i+2}_{j}.csv',encoding='cp949')

# %%
df[['부채/자산2015',	'부채/매출액2015'	,'유동부채/부채2015',	'유동자산/자산2015']].describe()
df = df[['구분', '이자보상배율2015', '영업이익2015', '차입금의존도2015', '총자본증가율2015','유동자산증가율2015', '매출액증가율2015', '순이익증가율2015', '영업이익증가율2015', '매출액순이익률2015','매출액총이익률2015', '자기자본순이익률2015', '총자본순이익률2015', '매출원가 대 매출액비율2015','매출채권회전률2015', '재고자산회전률2015', '총자본회전률2015', '유형자산회전율2015', '부채비율2015','유동비율2015', '자기자본배율2015', '당좌비율2015', '비유동비율2015', '순운전자본비율2015','현금비율2015','부채/자산2015', '부채/매출액2015', '부채/현금흐름2015', '유동부채/부채2015', '유동자산/자산2015','매출/현금흐름2015', '차입금평균이자율2015', '정상기업여부']]

for i in df.columns:
    print(df[df[i]==-math.inf])
# Out:
# Empty DataFrame
# Columns: [구분, 이자보상배율2015, 영업이익2015, 차입금의존도2015, 총자본증가율2015, 유동자산증가율2015, 매출액증가율2015, 순이익증가율2015, 영업이익증가율2015, 매출액순이익률2015, 매출액총이익률2015, 자기자본순이익률2015, 총자본순이익률2015, 매출원가 대 매출액비율2015, 매출채권회전률2015, 재고자산회전률2015, 총자본회전률2015, 유형자산회전율2015, 부채비율2015, 유동비율2015, 자기자본배율2015, 당좌비율2015, 비유동비율2015, 순운전자본비율2015, 현금비율2015, 부채/자산2015, 부채/매출액2015, 부채/현금흐름2015, 유동부채/부채2015, 유동자산/자산2015, 매출/현금흐름2015, 차입금평균이자율2015, 정상기업여부]
# Index: []
#
# [0 rows x 33 columns]
# Empty DataFrame
# Columns: [구분, 이자보상배율2015, 영업이익2015, 차입금의존도2015, 총자본증가율2015, 유동자산증가율2015, 매출액증가율2015, 순이익증가율2015, 영업이익증가율2015, 매출액순이익률2015, 매출액총이익률2015, 자기자본순이익률2015, 총자본순이익률2015, 매출원가 대 매출액비율2015, 매출채권회전률2015, 재고자산회전률2015, 총자본회전률2015, 유형자산회전율2015, 부채비율2015, 유동비율2015, 자기자본배율2015, 당좌비율2015, 비유동비율2015, 순운전자본비율2015, 현금비율2015, 부채/자산2015, 부채/매출액2015, 부채/현금흐름2015, 유동부채/부채2015, 유동자산/자산2015, 매출/현금흐름2015, 차입금평균이자율2015, 정상기업여부]
# Index: []
#
# [0 rows x 33 columns]
# Empty DataFrame
# ...
