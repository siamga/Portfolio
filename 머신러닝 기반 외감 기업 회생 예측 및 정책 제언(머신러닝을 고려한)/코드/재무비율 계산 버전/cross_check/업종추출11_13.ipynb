# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업업종 종합/기업명11_13_1.csv',encoding='cp949')
df1.dropna(inplace=True)
df1.reset_index(drop=True,inplace=True)

df1
# Out:
#               회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0       (주)21세기조선  40736  2010/12                   제조업
# 1           (주)3Z  12815  2010/12                   제조업
# 2     (주)ATS엔지니어링  61907  2010/12                   제조업
# 3      (주)DCFTREK  17676  2010/12                   제조업
# 4        (주)DH케미칼  40581  2010/12                   제조업
# ...           ...    ...      ...                   ...
# 3438   명신정보통신주식회사  56249  2010/12                   건설업
# 3439      명인전선(주)  49229  2010/12                   제조업
# 3440     명인제약주식회사  14581  2010/12                   제조업
# 3441    명일금속공업(주)  62328  2010/12                   제조업
# 3442     명일물류주식회사  61625  2010/12              운수 및 창고업
#
# [3443 rows x 4 columns]

# %%
df2 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업업종 종합/기업명11_13_2.csv',encoding='cp949')
df2.dropna(inplace=True)
df2.reset_index(drop=True,inplace=True)

df2
# Out:
#               회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0         (유)비티투자  54082  2010/12                  부동산업
# 1         (주)명지문화  14584  2010/12                   제조업
# 2       (주)명지엘펜하임  46456  2010/12                  부동산업
# 3         (주)명진금속  51691  2010/12              도매 및 소매업
# 4        (주)명진커넥터  45595  2010/12                   제조업
# ...           ...    ...      ...                   ...
# 3409   에셋큐브운용주식회사  58487  2010/12                  부동산업
# 3410  에스더불유아이주식회사  15952  2010/12                   제조업
# 3411   에스더블유팜주식회사  15386  2010/12              도매 및 소매업
# 3412   에스더블유해운(주)  44539  2010/12              운수 및 창고업
# 3413  에스디바이오센서(주)  57968  2010/12                   제조업
#
# [3414 rows x 4 columns]

# %%
df3 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업업종 종합/기업명11_13_3.csv',encoding='cp949')
df3.dropna(inplace=True)
df3.reset_index(drop=True,inplace=True)

df3
# Out:
#                회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0         (유)에스아이지  58564  2010/12                   제조업
# 1        (유)유맥에프앤알  14534  2010/12                  부동산업
# 2         (주)에스디비즈  61648  2010/12              도매 및 소매업
# 3       (주)에스디산업개발  50555  2010/12                  부동산업
# 4     (주)에스디엔제이홀딩스  56760  2010/12   예술, 스포츠 및 여가관련 서비스업
# ...            ...    ...      ...                   ...
# 3293      주식회사대창철강  51753  2010/12                   제조업
# 3294        주식회사대철  17678  2010/12                   제조업
# 3295      주식회사대청공영  45355  2010/12                   건설업
# 3296     주식회사대청하이텍  57045  2010/12                   제조업
# 3297        주식회사대촌  13830  2010/12                   제조업
#
# [3298 rows x 4 columns]

# %%
df4 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업업종 종합/기업명11_13_4.csv',encoding='cp949')
df4.dropna(inplace=True)
df4.reset_index(drop=True,inplace=True)

df4
# Out:
#                회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0         (유)에스아이지  58564  2010/12                   제조업
# 1        (유)유맥에프앤알  14534  2010/12                  부동산업
# 2         (주)에스디비즈  61648  2010/12              도매 및 소매업
# 3       (주)에스디산업개발  50555  2010/12                  부동산업
# 4     (주)에스디엔제이홀딩스  56760  2010/12   예술, 스포츠 및 여가관련 서비스업
# ...            ...    ...      ...                   ...
# 3293      주식회사대창철강  51753  2010/12                   제조업
# 3294        주식회사대철  17678  2010/12                   제조업
# 3295      주식회사대청공영  45355  2010/12                   건설업
# 3296     주식회사대청하이텍  57045  2010/12                   제조업
# 3297        주식회사대촌  13830  2010/12                   제조업
#
# [3298 rows x 4 columns]

# %%
df5 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업업종 종합/기업명11_13_5.csv',encoding='cp949')
df5.dropna(inplace=True)
df5.reset_index(drop=True,inplace=True)

df5
# Out:
#                 회사명  거래소코드     회계년도  통계청 한국표준산업분류 10차(대분류)
# 0     (유)짐머바이오메트코리아  18711  2010/12               도매 및 소매업
# 1         (유)케이원에너지  47069  2010/12               도매 및 소매업
# 2            (주)진데크  52321  2010/12                    건설업
# 3          (주)진도선파크  60022  2010/12  전기, 가스, 증기 및 공기조절 공급업
# 4         (주)진두아이에스  52071  2010/12                  정보통신업
# ...             ...    ...      ...                    ...
# 3182        희창냉장(주)  20563  2010/12               운수 및 창고업
# 3183       희창물산주식회사  20564  2010/12               도매 및 소매업
# 3184      희창씨앤에프(주)  52850  2010/12               운수 및 창고업
# 3185       희천개발주식회사  60017  2010/12                   부동산업
# 3186      힐티코리아주식회사  10534  2010/12               도매 및 소매업
#
# [3187 rows x 4 columns]

# %%
import numpy as np

df_w = pd.concat([df1,df2,df3],axis=0)
df_w.reset_index(inplace=True,drop=True)
df_w.rename(columns={'회사명':'구분'},inplace=True)
df_w.rename(columns={'통계청 한국표준산업분류 10차(대분류)':'업종'},inplace=True)
df_w.set_index('구분',inplace=True)
df_w = df_w['업종']
df_w
# len(np.unique(df_w.index))
# Out:
# 구분
# (주)21세기조선      제조업
# (주)3Z          제조업
# (주)ATS엔지니어링    제조업
# (주)DCFTREK     제조업
# (주)DH케미칼       제조업
#               ...
# 주식회사대창철강       제조업
# 주식회사대철         제조업
# 주식회사대청공영       건설업
# 주식회사대청하이텍      제조업
# 주식회사대촌         제조업
# Name: 업종, Length: 10155, dtype: object

# %%
df13 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/땡처리 삭제/충격기간/11_13/11_13_이자.csv',encoding='cp949').drop('Unnamed: 0',axis=1)
df13.set_index('구분',inplace=True)
df13 = df13.join(df_w,how='left')
df13['업종'][df13['업종'] != '제조업'] = 1
df13['업종'][df13['업종'] == '제조업'] = 0
ind = df13['업종']
df13.drop('업종',axis=1,inplace=True)
df13.insert(loc=31,column='업종',value=ind)
df13
# 비제조업 1, 제조업 0
df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/더미화/충격기간/11_13이자(업종더미).csv',encoding='cp949')
df13
# df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/충격기간/00_02_이자(업종포함).csv',encoding='cp949')
# 업종 추가 결과 데이터 숫자가 더 늘어나게 되는데
# 특정 기업이 여러 업종에서 사업을 진행할 경우 
# 해당 업종별로 개별 데이터로 취급하기 때문이다.
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_16292\1084588152.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_16292\1084588152.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] == '제조업'] = 0
#              총자산증가율2013  유동자산증가율2013  매출액증가율2013  매출액순이익률2013  매출총이익률2013  \
# 구분
# (주)ENS        -0.019716     0.001116   -0.088468     0.008199    0.354196
# (주)G1네트웍스      0.170970     0.634374   -0.041372    -0.018864    0.117596
# (주)IEN한창      -0.029745    -0.039138   -0.031394    -0.074348    0.203314
# ...

# %%
df13 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/땡처리 삭제/충격기간/11_13/11_13_영손.csv',encoding='cp949').drop('Unnamed: 0',axis=1)
df13.set_index('구분',inplace=True)
df13 = df13.join(df_w,how='left')
df13['업종'][df13['업종'] != '제조업'] = 1
df13['업종'][df13['업종'] == '제조업'] = 0
ind = df13['업종']
df13.drop('업종',axis=1,inplace=True)
df13.insert(loc=31,column='업종',value=ind)
df13
# 비제조업 1, 제조업 0
df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/더미화/충격기간/11_13영손(업종더미).csv',encoding='cp949')
df13
# df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/충격기간/00_02_영손(업종포함).csv',encoding='cp949')
# 업종 추가 결과 데이터 숫자가 더 늘어나게 되는데
# 특정 기업이 여러 업종에서 사업을 진행할 경우 
# 해당 업종별로 개별 데이터로 취급하기 때문이다.
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_16292\4085720426.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_16292\4085720426.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] == '제조업'] = 0
#              총자산증가율2013  유동자산증가율2013  매출액증가율2013  매출액순이익률2013  매출총이익률2013  \
# 구분
# (주)G1네트웍스      0.170970     0.634374   -0.041372    -0.018864    0.117596
# (주)KH엘텍        0.415425     1.525045    2.756221     0.168835    0.213759
# (주)SIMPAC산기    0.161903     1.168194    2.155182    -0.314684    0.041971
# ...
