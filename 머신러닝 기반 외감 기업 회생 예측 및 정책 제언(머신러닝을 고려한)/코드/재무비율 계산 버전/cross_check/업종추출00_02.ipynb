# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업업종 종합/기업명00_02_1.csv',encoding='cp949')
df1.dropna(inplace=True)
df1.reset_index(drop=True,inplace=True)

df1
# Out:
#                    회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0           (주)DCFTREK  17676  2000/12                   제조업
# 1               (주)KHE  27325  2000/12                   제조업
# 2               (주)KTE  26849  2000/12                   제조업
# 3           (주)MBC아카데미  20587  2000/12               교육 서비스업
# 4            (주)MBC애드컴  20588  2000/12      전문, 과학 및 기술 서비스업
# ...                ...    ...      ...                   ...
# 2524        엘지디스플레이(주)  10006  2000/12                   제조업
# 2525  엘지아이비엠퍼스널컴퓨터주식회사  16446  2000/12              도매 및 소매업
# 2526         엘지유니참주식회사  16897  2000/12                   제조업
# 2527          엘지이노텍(주)  10193  2000/12                   제조업
# 2528      엘지폴리카보네이트(주)  16443  2000/12                   제조업
#
# [2529 rows x 4 columns]

# %%
df2 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업업종 종합/기업명00_02_2.csv',encoding='cp949')
df2.dropna(inplace=True)
df2.reset_index(drop=True,inplace=True)

df2
# Out:
#                     회사명  거래소코드     회계년도     통계청 한국표준산업분류 10차(대분류)
# 0             (유)유맥에프앤알  14534  2000/12                      부동산업
# 1         (유)짐머바이오메트코리아  18711  2000/12                  도매 및 소매업
# 2                (주)엘케이  16453  2000/12                       제조업
# 3              (주)엠.피.씨  11889  2000/12  사업시설 관리, 사업 지원 및 임대 서비스업
# 4              (주)엠비씨경남  14519  2000/12                     정보통신업
# ...                 ...    ...      ...                       ...
# 2747         프라다코리아유한회사  19616  2000/12                  도매 및 소매업
# 2748           프라임개발(주)  10071  2000/12                       건설업
# 2749          프라임포텍주식회사  11762  2000/12                       제조업
# 2750     프레지니우스카비코리아(주)  10202  2000/12                  도매 및 소매업
# 2751  프렉스에어서피스테크놀로지스(주)  19625  2000/12                       제조업
#
# [2752 rows x 4 columns]

# %%
df3 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업업종 종합/기업명00_02_3.csv',encoding='cp949')
df3.dropna(inplace=True)
df3.reset_index(drop=True,inplace=True)

df3
# Out:
#              회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차(대분류)
# 0    (유)한국비엠에스제약  18712  2000/12              도매 및 소매업
# 1         (주)프리챌  12324  2000/12                 정보통신업
# 2       (주)플럼디자인  11386  2000/12      전문, 과학 및 기술 서비스업
# 3      (주)피.디.에이  10783  2000/12                   제조업
# 4    (주)피더블유제네틱스  17562  2000/12                 정보통신업
# ..           ...    ...      ...                   ...
# 614     희성촉매주식회사  20560  2000/12                   제조업
# 615     희창물산주식회사  20564  2000/12              도매 및 소매업
# 616  희훈아티퍼니처주식회사  20565  2000/12                   제조업
# 617   희훈종합건설주식회사  20566  2000/12                   건설업
# 618    힐티코리아주식회사  10534  2000/12              도매 및 소매업
#
# [619 rows x 4 columns]

# %%
import numpy as np

df_w = pd.concat([df1,df2,df3],axis=0)
df_w.reset_index(inplace=True,drop=True)
df_w.rename(columns={'회사명':'구분'},inplace=True)
df_w.rename(columns={'통계청 한국표준산업분류 10차(대분류)':'업종'},inplace=True)
df_w.set_index('구분',inplace=True)
df_w = df_w['업종']
df_w
# len(np.unique(df_w.index))
# Out:
# 구분
# (주)DCFTREK                  제조업
# (주)KHE                      제조업
# (주)KTE                      제조업
# (주)MBC아카데미              교육 서비스업
# (주)MBC애드컴      전문, 과학 및 기술 서비스업
#                      ...
# 희성촉매주식회사                    제조업
# 희창물산주식회사               도매 및 소매업
# 희훈아티퍼니처주식회사                 제조업
# 희훈종합건설주식회사                  건설업
# 힐티코리아주식회사              도매 및 소매업
# Name: 업종, Length: 5900, dtype: object

# %%
df13 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/땡처리 삭제/충격기간/00_02_이자.csv',encoding='cp949')
df13.set_index('구분',inplace=True)
df13 = df13.join(df_w,how='left')
df13['업종'][df13['업종'] != '제조업'] = 1
df13['업종'][df13['업종'] == '제조업'] = 0
ind = df13['업종']
df13.drop('업종',axis=1,inplace=True)
df13.insert(loc=31,column='업종',value=ind)
df13
# 비제조업 1, 제조업 0
# df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/더미화/충격기간/00_02이자(업종더미).csv',encoding='cp949')
# df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/충격기간/00_02_이자(업종포함).csv',encoding='cp949')
# 업종 추가 결과 데이터 숫자가 더 늘어나게 되는데
# 특정 기업이 여러 업종에서 사업을 진행할 경우 
# 해당 업종별로 개별 데이터로 취급하기 때문이다.
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_16188\3727535550.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_16188\3727535550.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] == '제조업'] = 0
#             총자산증가율2002  유동자산증가율2002  매출액증가율2002  매출액순이익률2002  매출총이익률2002  \
# 구분
# (유)유맥에프앤알    -0.093305    -0.096634    0.133182     0.012732    0.152439
# (주)KHE       -0.317719    -0.393731   -0.253121    -0.470462   -0.095044
# (주)NH무역       0.302559     0.312478    0.607479     0.018273    0.099056
# (주)건잠디지털     -0.420778    -0.321275   -0.499324    -1.488662    0.111761
# (주)게스템프카테크   -0.024956     0.116838    0.557882     0.031276    0.102605
# ...                ...          ...         ...          ...         ...
# 현대합성공업(주)     0.103463     0.227657   -0.002216     0.008028    0.106433
# 화남산업주식회사     -0.125152    -0.034013   -0.008704    -0.199802    0.190758
# 후지테크코리아(주)    0.057699     0.118045   -0.132631     0.068508    0.131423
# 휘닉스중앙주식회사    -0.066133     1.577388    0.191650    -0.044267    0.889370
# 희훈종합건설주식회사   -0.186132    -0.190779   -0.188818     0.037455    0.082911
#
#             자기자본순이익률2002  총자산순이익률2002  매출원가대매출액비율2002  매출액대판매관리비2002  \
# 구분
# (유)유맥에프앤알       0.183960     0.037000        0.847561       0.142625
# (주)KHE         -3.532703    -0.379093        1.095044       0.291812
# (주)NH무역         0.098524     0.035109        0.900944       0.081466
# (주)건잠디지털       -2.204502    -0.762128        0.888239       0.771760
# (주)게스템프카테크      0.149613     0.037139        0.897395       0.050704
# ...                  ...          ...             ...            ...
# 현대합성공업(주)       0.050953     0.015035        0.893567       0.103714
# 화남산업주식회사       -0.150764    -0.129271        0.809242       0.236552
# 후지테크코리아(주)      0.267951     0.086237        0.868577       0.076614
# 휘닉스중앙주식회사      -0.057253    -0.006522        0.110630       0.998159
# 희훈종합건설주식회사      0.421518     0.063752        0.917089       0.051278
#
#             매출채권회전율2002  ...  부채/현금흐름2002  유동부채/부채2002  총부채/총자산2002  \
# 구분                       ...
# (유)유맥에프앤알    211.046560  ...  -300.964865     1.265295     0.798869
# (주)KHE         2.258060  ...    -7.716314     1.116081     0.892690
# (주)NH무역        7.559893  ...   -15.402955     1.199667     0.643645
# (주)건잠디지털       1.462560  ...    -1.948070     1.159615     0.654286
# (주)게스템프카테크     9.651881  ...  -362.460165     1.024086     0.751766
# ...                 ...  ...          ...          ...          ...
# 현대합성공업(주)      8.000791  ...     4.088199     3.046147     0.704932
# 화남산업주식회사       8.177560  ...    20.653876     2.092891     0.142559
# 후지테크코리아(주)     3.312108  ...     2.689212     6.064430     0.678162
# 휘닉스중앙주식회사     14.868380  ...   444.059421     1.775800     0.886080
# 희훈종합건설주식회사     2.536680  ...     2.192837    15.101298     0.848756
#
#             유동부채/총부채2002  유동자산/총자산2002  현금흐름/매출액2002  이자보상배율2002  차입금평균금리2002  \
# 구분
# (유)유맥에프앤알       0.921664      0.102310     -0.000665    0.742717         5.86
# (주)KHE          0.846032      0.445706     -0.108833   -6.908263         7.21
# (주)NH무역         0.979706      0.977379     -0.017760    1.608553         3.64
# (주)건잠디지털        0.470543      0.540445     -0.266206   -5.377087        11.85
# (주)게스템프카테크      0.691897      0.183571     -0.001180    1.496306         7.72
# ...                  ...           ...           ...         ...          ...
# 현대합성공업(주)       0.683823      0.538738      0.020670    0.483663         7.47
# 화남산업주식회사        0.915115      0.642700      0.004665   -6.888342         6.91
# 후지테크코리아(주)      0.635718      0.582942      0.021000   11.769839         5.58
# 휘닉스중앙주식회사       0.186794      0.063107      0.001425   -1.284226        10.34
# 희훈종합건설주식회사      0.960793      0.952633      0.014468   15.607291         5.36
#
#             업종  정상기업여부
# 구분
# (유)유맥에프앤알    1       0
# (주)KHE       0       0
# (주)NH무역      1       1
# (주)건잠디지털     0       0
# (주)게스템프카테크   0       1
# ...         ..     ...
# 현대합성공업(주)    0       0
# 화남산업주식회사     0       0
# 후지테크코리아(주)   0       1
# 휘닉스중앙주식회사    1       0
# 희훈종합건설주식회사   1       1
#
# [450 rows x 33 columns]

# %%
df13 = pd.read_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/땡처리 삭제/충격기간/00_02_영손.csv',encoding='cp949')
df13.set_index('구분',inplace=True)
df13 = df13.join(df_w,how='left')
df13['업종'][df13['업종'] != '제조업'] = 1
df13['업종'][df13['업종'] == '제조업'] = 0
ind = df13['업종']
df13.drop('업종',axis=1,inplace=True)
df13.insert(loc=31,column='업종',value=ind)
df13
# 비제조업 1, 제조업 0
df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/더미화/충격기간/00_02영손(업종더미).csv',encoding='cp949')
# df13.to_csv('C:/Users/LG/Desktop/금융 빅데이터/프로젝트2/코드/재무비율 계산 버전/cross_check/기업재무비율_업종포함/충격기간/00_02_영손(업종포함).csv',encoding='cp949')
# 업종 추가 결과 데이터 숫자가 더 늘어나게 되는데
# 특정 기업이 여러 업종에서 사업을 진행할 경우 
# 해당 업종별로 개별 데이터로 취급하기 때문이다.
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_16188\3612251973.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] != '제조업'] = 1
# C:\Users\LG\AppData\Local\Temp\ipykernel_16188\3612251973.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['업종'][df13['업종'] == '제조업'] = 0
